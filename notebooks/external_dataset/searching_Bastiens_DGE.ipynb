# %%
import re
import pandas as pd
from pathlib import Path
from typing import Iterable, Optional, Union, List

def search_workbook(
    xlsx_path: Union[str, Path],
    queries: Union[str, Iterable[str]],
    columns: Optional[Iterable[str]] = None,    # search only these columns (None = all)
    whole_word: bool = True,                    # match as whole word (e.g., LDHA not “oldham”)
    case_sensitive: bool = False,               # LDHA == ldha if False
    use_regex: bool = False,                    # supply your own regex in `queries`
    return_first_only: bool = False,            # stop at first match per sheet
) -> pd.DataFrame:
    """
    Scan every sheet of an Excel file for `queries`.
    Return a DataFrame of all matching rows, with extra columns:
      _sheet: sheet name
      _row   : original (0-based) row index in that sheet
      _query : which query matched
      _match_cols: comma-separated columns that matched in that row
    """
    xlsx_path = Path(xlsx_path)
    if isinstance(queries, str):
        queries = [queries]
    queries = list(queries)

    # build compiled patterns
    flags = 0 if case_sensitive else re.IGNORECASE
    patterns: List[re.Pattern] = []
    for q in queries:
        if use_regex:
            pat = re.compile(q, flags)
        else:
            if whole_word:
                # word boundaries around the query; allow gene-like tokens (letters/digits/_-)
                pat = re.compile(rf"\b{re.escape(q)}\b", flags)
            else:
                pat = re.compile(re.escape(q), flags)
        patterns.append(pat)

    # iterate sheets
    xls = pd.ExcelFile(xlsx_path)
    all_hits = []
    for sheet in xls.sheet_names:
        df = pd.read_excel(xls, sheet_name=sheet, dtype=str)  # read as strings for robust matching
        if df.empty:
            continue

        # restrict columns if requested (silently ignore missing)
        search_cols = list(columns) if columns is not None else list(df.columns)
        search_cols = [c for c in search_cols if c in df.columns]
        if not search_cols:
            continue

        # pre-clean values (trim whitespace)
        sub = df[search_cols].apply(lambda s: s.str.strip())

        for q, pat in zip(queries, patterns):
            # boolean mask: any column contains the pattern
            col_hits = {c: sub[c].str.contains(pat, na=False, regex=True) for c in search_cols}
            any_hit_mask = pd.DataFrame(col_hits).any(axis=1)

            if not any_hit_mask.any():
                continue

            hits = df.loc[any_hit_mask].copy()
            hits["_sheet"] = sheet
            hits["_row"] = hits.index
            hits["_query"] = q
            # record which columns matched for each row
            match_cols = []
            for idx in hits.index:
                cols = [c for c in search_cols if bool(col_hits[c].loc[idx])]
                match_cols.append(",".join(cols))
            hits["_match_cols"] = match_cols
            all_hits.append(hits)

            if return_first_only:
                # keep only the first matching row in this sheet for this query
                break

    if not all_hits:
        return pd.DataFrame(columns=["_sheet","_row","_query","_match_cols"])

    out = pd.concat(all_hits, ignore_index=True)

    # move helper columns to the front
    helper_cols = ["_sheet","_row","_query","_match_cols"]
    out = out[[*helper_cols, *[c for c in out.columns if c not in helper_cols]]]
    return out

# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
# hits = search_workbook("my_workbook.xlsx", queries="LDHA")

# 2) multiple genes (LDHA + LDHB), only search specific columns
# hits = search_workbook("my_workbook.xlsx", queries=["LDHA","LDHB"], columns=["Gene", "Symbol"])

# 3) save results
# hits.to_excel("matches_LDHA.xlsx", index=False)

# 4) regex search (e.g., LDH(A|B) exactly)
# hits = search_workbook("my_workbook.xlsx", queries=r"^LDH[AB]$", use_regex=True, whole_word=False)

# 5) show which sheet(s) contained LDHA
# sheets_with_ldha = hits.loc[hits["_query"]=="LDHA","_sheet"].unique()
# print(sheets_with_ldha)

# %%
# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
hits = search_workbook('/Users/christoffer/Downloads/Supplementary Table.xlsx', queries="Ldha")

# 2) multiple genes (LDHA + LDHB), only search specific columns
# hits = search_workbook("my_workbook.xlsx", queries=["LDHA","LDHB"], columns=["Gene", "Symbol"])

# 3) save results
# hits.to_excel("matches_LDHA.xlsx", index=False)

# 4) regex search (e.g., LDH(A|B) exactly)
# hits = search_workbook("my_workbook.xlsx", queries=r"^LDH[AB]$", use_regex=True, whole_word=False)

# 5) show which sheet(s) contained LDHA
# sheets_with_ldha = hits.loc[hits["_query"]=="LDHA","_sheet"].unique()
# print(sheets_with_ldha)

# %%
# Out:
#                _sheet  _row _query  \
# 19  Tab3-DGE_GRC_MOL2   345   Ldha
#
#                                           _match_cols  \
# 19  Average gene regulatory chromatin score of dif...
#
#    La sélection que vous tentez de copier-coller est trop grande. Sélectionnez moins de données, puis réessayez.  \
# 19                                                NaN
#
#             Unnamed: 1        Unnamed: 2         Unnamed: 3  \
# 19  0.0993006574139845  0.16220732431551  0.206144579115211
#
#            Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 19  0.137785811986747        NaN        NaN
#
#    Marker genes/promoters differentially accessible in each subOLG population  \
# 19                                                NaN
#
#    Pseudobulk aggregation of the expression of differentially expressed genes in MOL56 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 19                                                NaN
#
#    Pseudobulk aggregation of the expression of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 19                                                NaN
#
#    Pseudobulk aggregation of the accessibility of differentially expressed genes in MOL56 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 19                                                NaN
#
#    Pseudobulk aggregation of the accessibility of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 19                                                NaN
#
#    Average gene regulatory chromatin score of differentially expressed genes in MOL56 between timepoints  \
# 19                                                NaN
#
#    Average gene regulatory chromatin score of differentially expressed genes in MOL2 between timepoints
# 19                                               Ldha

# %%
# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
hits_Ldha = search_workbook('/Users/christoffer/Downloads/Supplementary Table.xlsx', queries="Ldha")

# %%
hits_Ldha
# Out:
#                 _sheet   _row _query  \
# 0      Tab2-DGE_subOLG    800   Ldha
# 1      Tab2-DGE_subOLG   4099   Ldha
# 2      Tab2-DGE_subOLG   7566   Ldha
# 3      Tab2-DGE_subOLG  11029   Ldha
# 4      Tab2-DGE_subOLG  13903   Ldha
# 5      Tab2-DGE_subOLG  15173   Ldha
# 6      Tab2-DGE_subOLG  19844   Ldha
# 7      Tab2-DGE_subOLG  20899   Ldha
# 8      Tab2-DGA_subOLG   1230   Ldha
# 9      Tab2-DGA_subOLG   4800   Ldha
# 10     Tab2-DGA_subOLG   9595   Ldha
# 11     Tab2-DGA_subOLG  13531   Ldha
# 12     Tab2-DGA_subOLG  17188   Ldha
# 13     Tab2-DGA_subOLG  22711   Ldha
# 14  Tab3-DGE_RNA_MOL56    568   Ldha
# 15   Tab3-DGE_RNA_MOL2    426   Ldha
# 16  Tab3-DGE_ACC_MOL56    425   Ldha
# 17   Tab3-DGE_ACC_MOL2    359   Ldha
# 18  Tab3-DGE_GRC_MOL56    402   Ldha
# 19   Tab3-DGE_GRC_MOL2    345   Ldha
#
#                                           _match_cols  \
# 0                                          Unnamed: 6
# 1                                          Unnamed: 6
# 2                                          Unnamed: 6
# 3                                          Unnamed: 6
# 4                                          Unnamed: 6
# 5                                          Unnamed: 6
# 6                                          Unnamed: 6
# 7                                          Unnamed: 6
# 8                                          Unnamed: 6
# 9                                          Unnamed: 6
# 10                                         Unnamed: 6
# 11                                         Unnamed: 6
# 12                                         Unnamed: 6
# 13                                         Unnamed: 6
# 14  Pseudobulk aggregation of the expression of di...
# 15  Pseudobulk aggregation of the expression of di...
# 16  Pseudobulk aggregation of the accessibility of...
# 17  Pseudobulk aggregation of the accessibility of...
# 18  Average gene regulatory chromatin score of dif...
# 19  Average gene regulatory chromatin score of dif...
#
#    La sélection que vous tentez de copier-coller est trop grande. Sélectionnez moins de données, puis réessayez.  \
# 0                                                   0
# 1                               4.98034015699615e-121
# 2                                                   0
# 3                               3.49844274468997e-134
# 4                                6.58080673500653e-07
# 5                                                   0
# 6                                5.41385843689784e-89
# 7                                 6.4777224021437e-32
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#             Unnamed: 1         Unnamed: 2          Unnamed: 3  \
# 0     2.05857388448025              0.316               0.065
# 1     2.25970481325952              0.426               0.069
# 2     2.57194392330653              0.427               0.066
# 3     1.56179349527516              0.272               0.068
# 4    0.865973326817555              0.171               0.069
# 5     2.07729253650233              0.181               0.059
# 6    0.875087486938761              0.124               0.065
# 7     2.19303669620552              0.194               0.069
# 8     1.59775773499821               0.33               0.145
# 9     1.78244030623465              0.363               0.148
# 10    1.14434764229221              0.288               0.147
# 11    1.26102119443311               0.29               0.147
# 12    0.68139391988572              0.221               0.141
# 13    1.63534370680884              0.323               0.147
# 14  0.0831551246034986   0.23383135952893  0.0957070505177873
# 15  0.0486157250011995  0.139698983183285   0.148721493434499
# 16   0.115755366775488  0.166487217412375  0.0958376757166866
# 17  0.0969305591707728  0.150817509986064    0.17382494286085
# 18   0.135552705016111  0.189151926911422   0.104073311154538
# 19  0.0993006574139845   0.16220732431551   0.206144579115211
#
#                Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                       0      OPC-α       Ldha
# 1   1.60790281968621e-116      OPC-β       Ldha
# 2                       0      OPC-γ       Ldha
# 3   1.12947224012316e-129        COP       Ldha
# 4      0.0212461345439686    MOL56-η       Ldha
# 5                       0    MOL56-κ       Ldha
# 6    1.74786419635247e-84     MOL2-ε       Ldha
# 7    2.09133267753209e-27       MOL1       Ldha
# 8   2.58735072522455e-131      OPC-α       Ldha
# 9     2.1936208537063e-21      OPC-β       Ldha
# 10   3.24357679836271e-35      OPC-γ       Ldha
# 11   4.84600086589814e-34        COP       Ldha
# 12  2.11082679440468e-111    MOL56-κ       Ldha
# 13   1.26819696870555e-27       MOL1       Ldha
# 14     0.0891744877928002        NaN        NaN
# 15     0.0455764459701945        NaN        NaN
# 16      0.135881605782639        NaN        NaN
# 17      0.123991389234234        NaN        NaN
# 18      0.151766735031212        NaN        NaN
# 19      0.137785811986747        NaN        NaN
#
#    Marker genes/promoters differentially accessible in each subOLG population  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                               9.98591557400443e-136
# 9                                8.46630974027905e-26
# 10                               1.25186290944142e-39
# 11                               1.87032067383178e-38
# 12                              8.14676493402036e-116
# 13                               4.89462357663277e-32
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    Pseudobulk aggregation of the expression of differentially expressed genes in MOL56 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                               Ldha
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    Pseudobulk aggregation of the expression of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                               Ldha
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    Pseudobulk aggregation of the accessibility of differentially expressed genes in MOL56 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                               Ldha
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    Pseudobulk aggregation of the accessibility of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                               Ldha
# 18                                                NaN
# 19                                                NaN
#
#    Average gene regulatory chromatin score of differentially expressed genes in MOL56 between timepoints  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                               Ldha
# 19                                                NaN
#
#    Average gene regulatory chromatin score of differentially expressed genes in MOL2 between timepoints
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                               Ldha

# %%
# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
hits_Ldhb = search_workbook('/Users/christoffer/Downloads/Supplementary Table.xlsx', queries="Ldhb")

# %%
hits_Ldhb
# Out:
#                  _sheet   _row _query  \
# 0       Tab2-DGE_subOLG  12721   Ldhb
# 1       Tab2-DGE_subOLG  13840   Ldhb
# 2       Tab2-DGE_subOLG  15960   Ldhb
# 3       Tab2-DGE_subOLG  17905   Ldhb
# 4       Tab2-DGE_subOLG  20676   Ldhb
# 5       Tab2-DGA_subOLG   3127   Ldhb
# 6       Tab2-DGA_subOLG   7521   Ldhb
# 7       Tab2-DGA_subOLG  11516   Ldhb
# 8       Tab2-DGA_subOLG  17310   Ldhb
# 9       Tab2-DGA_subOLG  18746   Ldhb
# 10      Tab2-DGA_subOLG  23552   Ldhb
# 11  Tab2-DVDORCs_subOLG   7275   Ldhb
# 12    Tab3-DGE_RNA_MOL2   1286   Ldhb
# 13    Tab3-DGE_ACC_MOL2   1084   Ldhb
# 14    Tab3-DGE_GRC_MOL2   1045   Ldhb
# 15            Tab5-MOL2    277   Ldhb
# 16            Tab5-MOL2    334   Ldhb
# 17            Tab5-MOL2    377   Ldhb
#
#                                           _match_cols  \
# 0                                          Unnamed: 6
# 1                                          Unnamed: 6
# 2                                          Unnamed: 6
# 3                                          Unnamed: 6
# 4                                          Unnamed: 6
# 5                                          Unnamed: 6
# 6                                          Unnamed: 6
# 7                                          Unnamed: 6
# 8                                          Unnamed: 6
# 9                                          Unnamed: 6
# 10                                         Unnamed: 6
# 11                                         Unnamed: 6
# 12  Pseudobulk aggregation of the expression of di...
# 13  Pseudobulk aggregation of the accessibility of...
# 14  Average gene regulatory chromatin score of dif...
# 15                                         Unnamed: 1
# 16  Genes differentially expressed between MOL2 vs...
# 17                                         Unnamed: 3
#
#    La sélection que vous tentez de copier-coller est trop grande. Sélectionnez moins de données, puis réessayez.  \
# 0                               4.46686627532413e-301
# 1                                9.06768861565443e-11
# 2                                                   0
# 3                                                   0
# 4                                3.74456860773683e-65
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#            Unnamed: 1         Unnamed: 2         Unnamed: 3  \
# 0    1.01338017707491              0.489              0.279
# 1   0.822593542357518              0.524              0.289
# 2    1.91287834590951              0.638              0.254
# 3   0.730718095425351               0.59              0.273
# 4    2.01765180632838              0.552              0.288
# 5   0.696262977914919              0.302              0.229
# 6   0.672137280805897              0.291               0.23
# 7    0.76466175411987              0.271               0.23
# 8   0.948341126084442              0.431               0.21
# 9   0.970325336336131              0.436              0.219
# 10   1.17310067236951              0.338              0.229
# 11  0.663690219662826              0.613              0.625
# 12   1.30573938583154  0.958003256839709  0.501479200032013
# 13  0.355399863225519  0.306727710066773  0.282244961048902
# 14  0.623493637821508  0.506060931994047  0.489731731820037
# 15               Ldhb            Gm17135            Gm27008
# 16               Nck2            Htatip2             Hs3st5
# 17              Poc1a             Kif19a               Ldhb
#
#                Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0   1.44212777698839e-296    MOL56-γ       Ldhb
# 1    2.92750326956403e-06    MOL56-η       Ldhb
# 2                       0     MOL2-α       Ldhb
# 3                       0     MOL2-δ       Ldhb
# 4    1.20893397500784e-60       MOL1       Ldhb
# 5    1.39396536707159e-12      OPC-α       Ldhb
# 6                       1      OPC-β       Ldhb
# 7                       1      OPC-γ       Ldhb
# 8                       0     MOL2-α       Ldhb
# 9                       0     MOL2-δ       Ldhb
# 10   1.78641653405457e-06       MOL1       Ldhb
# 11                      1       MOL1       Ldhb
# 12      0.627814634650816        NaN        NaN
# 13      0.271851582396482        NaN        NaN
# 14      0.533370170326927        NaN        NaN
# 15                    NaN        NaN        NaN
# 16                    NaN        NaN        NaN
# 17                    NaN        NaN        NaN
#
#    Marker genes/promoters differentially accessible in each subOLG population  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                5.38002843331374e-17
# 6                                  0.0072848817549782
# 7                                0.000268994719750363
# 8                                                   0
# 9                                                   0
# 10                               6.89469908936537e-11
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#    Marker genes with differential average DORC scores in each subOLG population  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                 0.0004470108135939
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#    Pseudobulk aggregation of the expression of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                               Ldhb
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#    Pseudobulk aggregation of the accessibility of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                               Ldhb
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#    Average gene regulatory chromatin score of differentially expressed genes in MOL2 between timepoints  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                               Ldhb
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#    Genes differentially expressed between MOL2 vs. MOL56 at each timepoint
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                               Gpd2
# 16                                               Ldhb
# 17                                              Mtcl1

# %%
# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
hits_Slc16a1 = search_workbook('/Users/christoffer/Downloads/Supplementary Table.xlsx', queries="Slc16a1")
hits_Slc16a1
# Out:
#                 _sheet   _row   _query  \
# 0      Tab2-DGE_subOLG  12558  Slc16a1
# 1      Tab2-DGE_subOLG  12738  Slc16a1
# 2      Tab2-DGE_subOLG  16092  Slc16a1
# 3  Tab2-DVDORCs_subOLG   3037  Slc16a1
# 4  Tab2-DVDORCs_subOLG   3653  Slc16a1
# 5    Tab3-DGE_RNA_MOL2    664  Slc16a1
# 6    Tab3-DGE_ACC_MOL2    583  Slc16a1
# 7    Tab3-DGE_GRC_MOL2    561  Slc16a1
#
#                                          _match_cols  \
# 0                                         Unnamed: 6
# 1                                         Unnamed: 6
# 2                                         Unnamed: 6
# 3                                         Unnamed: 6
# 4                                         Unnamed: 6
# 5  Pseudobulk aggregation of the expression of di...
# 6  Pseudobulk aggregation of the accessibility of...
# 7  Average gene regulatory chromatin score of dif...
#
#   La sélection que vous tentez de copier-coller est trop grande. Sélectionnez moins de données, puis réessayez.  \
# 0                                                  0
# 1                              1.76839319425192e-220
# 2                                                  0
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#           Unnamed: 1         Unnamed: 2         Unnamed: 3  \
# 0  0.672699464015324              0.454              0.388
# 1  0.735497739586155              0.591                0.4
# 2  0.533229913285312              0.597               0.39
# 3  0.753698536568035              0.924              0.918
# 4  0.572081776524701              0.916              0.919
# 5  0.967394586549655  0.581893362802595   0.43058346534489
# 6  0.613900381839862  0.581415795111707  0.529230688860463
# 7   2.08778953787301   1.92954601822968   1.71952300316431
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                      0    MOL56-β    Slc16a1
# 1  5.70925742764233e-216    MOL56-γ    Slc16a1
# 2                      0     MOL2-α    Slc16a1
# 3   2.69982796543141e-49    MOL56-α    Slc16a1
# 4  3.30201005379888e-159    MOL56-β    Slc16a1
# 5      0.575268955502452        NaN        NaN
# 6      0.553049454280981        NaN        NaN
# 7       1.86735089738952        NaN        NaN
#
#   Marker genes with differential average DORC scores in each subOLG population  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                               8.01373691134285e-53
# 4                              9.80115777322316e-163
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#   Pseudobulk aggregation of the expression of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                            Slc16a1
# 6                                                NaN
# 7                                                NaN
#
#   Pseudobulk aggregation of the accessibility of differentially expressed genes in MOL2 between timepoints, normalized by the total number of counts multiplied by 10,000 and natural log transformed  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                            Slc16a1
# 7                                                NaN
#
#   Average gene regulatory chromatin score of differentially expressed genes in MOL2 between timepoints
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                            Slc16a1

# %%
# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
hits_Hif1a = search_workbook('/Users/christoffer/Downloads/Supplementary Table.xlsx', queries="Hif1a")
hits_Hif1a
# Out:
#             _sheet   _row _query _match_cols  \
# 0  Tab2-DGE_subOLG   2322  Hif1a  Unnamed: 6
# 1  Tab2-DGE_subOLG   9672  Hif1a  Unnamed: 6
# 2  Tab2-DGE_subOLG  11180  Hif1a  Unnamed: 6
# 3  Tab2-DGE_subOLG  21489  Hif1a  Unnamed: 6
#
#   La sélection que vous tentez de copier-coller est trop grande. Sélectionnez moins de données, puis réessayez.  \
# 0                               2.12783340186749e-58
# 1                               2.85326866692086e-31
# 2                              1.79438325659496e-103
# 3                               2.50500273032672e-07
#
#           Unnamed: 1 Unnamed: 2 Unnamed: 3            Unnamed: 4 Unnamed: 5  \
# 0  0.592175166316989      0.505      0.322  6.86971013792921e-54      OPC-α
# 1  0.615316916634019      0.514      0.324    9.211777891154e-27      OPC-γ
# 2   1.06034248213972      0.655      0.323  5.79316634391683e-99        COP
# 3   1.06702969704813      0.384      0.325   0.00808740131485981       MOL1
#
#   Unnamed: 6
# 0      Hif1a
# 1      Hif1a
# 2      Hif1a
# 3      Hif1a

# %%
# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
hits_Ppargc1a = search_workbook('/Users/christoffer/Downloads/Supplementary Table.xlsx', queries="Ppargc1a")
hits_Ppargc1a
# Out:
#                 _sheet   _row    _query _match_cols  \
# 0      Tab2-DGE_subOLG   1201  Ppargc1a  Unnamed: 6
# 1      Tab2-DGE_subOLG  13601  Ppargc1a  Unnamed: 6
# 2      Tab2-DGA_subOLG    722  Ppargc1a  Unnamed: 6
# 3      Tab2-DGA_subOLG   4894  Ppargc1a  Unnamed: 6
# 4      Tab2-DGA_subOLG   8449  Ppargc1a  Unnamed: 6
# 5      Tab2-DGA_subOLG  13583  Ppargc1a  Unnamed: 6
# 6      Tab2-DGA_subOLG  18836  Ppargc1a  Unnamed: 6
# 7      Tab2-DGA_subOLG  22148  Ppargc1a  Unnamed: 6
# 8  Tab2-DVDORCs_subOLG    285  Ppargc1a  Unnamed: 6
#
#   La sélection que vous tentez de copier-coller est trop grande. Sélectionnez moins de données, puis réessayez.  \
# 0                                                  0
# 1                              3.47330254617341e-185
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
#
#           Unnamed: 1 Unnamed: 2 Unnamed: 3             Unnamed: 4 Unnamed: 5  \
# 0   4.89726191863239      0.131      0.004                      0      OPC-α
# 1   4.50013325968023      0.189      0.006  1.12135572703209e-180    MOL56-η
# 2    1.9899533088568      0.346      0.117  5.64698225399878e-240      OPC-α
# 3    1.6372384870572      0.311      0.121     2.468224599919e-19      OPC-β
# 4   1.80125844346485      0.337      0.119  1.65703163573133e-107      OPC-γ
# 5   1.15739898735271       0.25       0.12   1.76839990002277e-32        COP
# 6   1.21522656311617      0.298      0.112                      0     MOL2-δ
# 7   2.62263105978831      0.408       0.12   2.74531250237832e-99       MOL1
# 8  0.510496736898928      0.374      0.069                      0      OPC-α
#
#   Unnamed: 6  \
# 0   Ppargc1a
# 1   Ppargc1a
# 2   Ppargc1a
# 3   Ppargc1a
# 4   Ppargc1a
# 5   Ppargc1a
# 6   Ppargc1a
# 7   Ppargc1a
# 8   Ppargc1a
#
#   Marker genes/promoters differentially accessible in each subOLG population  \
# 0                                                NaN
# 1                                                NaN
# 2                              2.17946053801574e-244
# 3                               9.52614666120803e-24
# 4                              6.39533630154896e-112
# 5                               6.82516364346882e-37
# 6                                                  0
# 7                              1.05955712172069e-103
# 8                                                NaN
#
#   Marker genes with differential average DORC scores in each subOLG population
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                  0

# %%
# ----- Example usage -----
# 1) simple: find LDHA anywhere, whole-word, case-insensitive
hits_Ppargc1a = search_workbook('/Users/christoffer/Downloads/Supplementary Table.xlsx', queries="Ppargc1a")
hits_Ppargc1a
